# %% [markdown]
# <a href="https://colab.research.google.com/github/bettycdaba/financial-inclusion-in-africa/blob/main/Financial-Inclusion0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# dataframe and plotting
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# machine learning
from lightgbm import LGBMClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

from google.colab import files
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd

# Load files into a pandas dataframe
train = pd.read_csv('./Train.csv')
test = pd.read_csv('./Test.csv')
ss = pd.read_csv('./SampleSubmission.csv')
variables = pd.read_csv('./VariableDefinitions.csv', encoding = "latin1")

# %%
#import preprocessing module
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler

# Cobvert target label to numerical Data
le = LabelEncoder()
train['bank_account'] = le.fit_transform(train['bank_account'])

#Separate training features from target
X_train = train.drop(['bank_account'], axis=1)
y_train = train['bank_account']


print(y_train)
# Out:
# 0        1
# 1        0
# 2        1
# 3        0
# 4        0
#         ..
# 23519    0
# 23520    0
# 23521    0
# 23522    0
# 23523    0
# Name: bank_account, Length: 23524, dtype: int64

# %%
# Let’s observe the shape of our datasets.
print('train data shape :', train.shape)
print('test data shape :', test.shape)
# Out:
# train data shape : (23524, 13)
# test data shape : (10086, 12)

# %%
# inspect train data
train.head()
# Out:
#   country  year    uniqueid  bank_account location_type cellphone_access  \
# 0   Kenya  2018  uniqueid_1             1         Rural              Yes
# 1   Kenya  2018  uniqueid_2             0         Rural               No
# 2   Kenya  2018  uniqueid_3             1         Urban              Yes
# 3   Kenya  2018  uniqueid_4             0         Rural              Yes
# 4   Kenya  2018  uniqueid_5             0         Urban               No
#
#    household_size  age_of_respondent gender_of_respondent  \
# 0               3                 24               Female
# 1               5                 70               Female
# 2               5                 26                 Male
# 3               5                 34               Female
# 4               8                 26                 Male
#
#   relationship_with_head           marital_status  \
# 0                 Spouse  Married/Living together
# 1      Head of Household                  Widowed
# ...

# %%
# Check for missing values
print('missing values:', train.isnull().sum())
# Out:
# missing values: country                   0
# year                      0
# uniqueid                  0
# bank_account              0
# location_type             0
# cellphone_access          0
# household_size            0
# age_of_respondent         0
# gender_of_respondent      0
# relationship_with_head    0
# marital_status            0
# education_level           0
# job_type                  0
# dtype: int64

# %%
# Explore Target distribution #Our target is the bank_account
sns.catplot(x="bank_account", kind="count", data=train)

# %%
# view the submission file
ss.head()
# Out:
#             unique_id  bank_account
# 0  uniqueid_1 x Kenya             0
# 1  uniqueid_2 x Kenya             0
# 2  uniqueid_3 x Kenya             0
# 3  uniqueid_4 x Kenya             0
# 4  uniqueid_5 x Kenya             0

# %%
#import preprocessing module
#from sklearn.preprocessing import LabelEncoder
#from sklearn.preprocessing import MinMaxScaler

# Cobvert target label to numerical Data
#le = LabelEncoder()
#train['bank_account'] = le.fit_transform(train['bank_account'])

#Separate training features from target
#X_train = train.drop(['bank_account'], axis=1)
#y_train = train['bank_account']


#print(y_train)

# %%
# function to preprocess our data from train models
#def preprocessing_data(data):

    # Convert the following numerical labels from interger to float
    #float_array = data[["household_size", "age_of_respondent", "year"]].values.astype(float)

    # categorical features to be onverted to One Hot Encoding
    #categ = ["relationship_with_head",
             #"marital_status",
             #"education_level",
             #"job_type",
             #"country"]

    # One Hot Encoding conversion
    #data = pd.get_dummies(data, prefix_sep="_", columns=categ)

    # Label Encoder conversion
    #data["location_type"] = le.fit_transform(data["location_type"])
    #data["cellphone_access"] = le.fit_transform(data["cellphone_access"])
    #data["gender_of_respondent"] = le.fit_transform(data["gender_of_respondent"])

    # drop uniquid column
    #data = data.drop(["uniqueid"], axis=1)

    # drop the year column
    #data = data.drop(["year"], axis=1)

    # scale our data into range of 0 and 1
    #scaler = MinMaxScaler(feature_range=(0, 1))
    #data = scaler.fit_transform(data)

    #return data

# %%
#preprocessing_data(train)

# %%
# preprocess the train data
#processed_train = preprocessing_data(X_train)
#processed_test = preprocessing_data(test)

# %%
#processed_test.shape

# %%
import sklearn.model_selection

# %%
# Split train_data
#from sklearn.model_selection import train_test_split

#X_train, X_val, y_train, y_val = train_test_split(
    #processed_train,
    #train['bank_account'], # Use the original full y_train
    #stratify=train['bank_account'], # Stratify by the original full y_train
    #test_size=0.2,
    #random_state=42
#)

#print(f"Training set size: {X_train.shape[0]}")
#print(f"Validation set size: {X_val.shape[0]}")

# %%
#import classifier algorithm here
#from xgboost import XGBClassifier

# create models
#xg_model = XGBClassifier()

#fitting the models
#xg_model.fit(X_train,y_train)

# %%
# import evaluation metrics
#from sklearn.metrics import confusion_matrix, accuracy_score

# evaluate the model
#xg_y_model = xg_model.predict(X_val)

# Get error rate
#print("Error rate of XGB classifier: ", 1 - accuracy_score(y_val, xg_y_model))

# %%
#from sklearn.metrics import confusion_matrix, accuracy_score

# fit by setting best parameters and Evaluate model
#xgb_model = XGBClassifier(min_child_weight=4, gamma=1, subsample=0.9, max_depth=4)

#xgb_model.fit(X_train, y_train)
#y_pred = xgb_model.predict(X_val)

# Get error rate
#print("Error rate of the XGB classifier: ", 1 - accuracy_score(y_val, y_pred))

# %%
# Get the predicted result for the test Data
#test.bank_account = xgb_model.predict(processed_test)

# %%
# Create submission DataFrame
#submission = pd.DataFrame({"uniqueid": test["uniqueid"] + " x " + test["country"],
                           #"bank_account": test.bank_account})

# %%
#show the five sample
#submission.sample(5)

# %%
# Create submission csv file csv file
#submission.to_csv('osubmission.csv', index = False)
#files.download('osubmission.csv')

# %%
# ============================================================================
# STEP 3: ENCODE TARGET
# ============================================================================
le = LabelEncoder()
train['bank_account'] = le.fit_transform(train['bank_account'])

# ============================================================================
# STEP 4: FEATURE ENGINEERING (IMPROVEMENT 1)
# ============================================================================
# Add these new features to improve model performance

# Create education level as number
education_order = {
    'No formal education': 0,
    'Primary education': 1,
    'Secondary education': 2,
    'Vocational/Specialised training': 3,
    'Tertiary education': 4,
    'Other/Dont know/RTA': -1
}
train['education_numeric'] = train['education_level'].map(education_order)
test['education_numeric'] = test['education_level'].map(education_order)

# Create age groups
train['age_group'] = pd.cut(train['age_of_respondent'], bins=[0, 25, 35, 50, 65, 120], labels=[0, 1, 2, 3, 4])
test['age_group'] = pd.cut(test['age_of_respondent'], bins=[0, 25, 35, 50, 65, 120], labels=[0, 1, 2, 3, 4])

# Create household size groups
train['household_group'] = pd.cut(train['household_size'], bins=[0, 3, 6, 10, 50], labels=[0, 1, 2, 3])
test['household_group'] = pd.cut(test['household_size'], bins=[0, 3, 6, 10, 50], labels=[0, 1, 2, 3])

# Create is_urban flag
train['is_urban'] = (train['location_type'] == 'Urban').astype(int)
test['is_urban'] = (test['location_type'] == 'Urban').astype(int)

# Create has_cellphone flag
train['has_cellphone'] = (train['cellphone_access'] == 'Yes').astype(int)
test['has_cellphone'] = (test['cellphone_access'] == 'Yes').astype(int)

# Create is_female flag
train['is_female'] = (train['gender_of_respondent'] == 'Female').astype(int)
test['is_female'] = (test['gender_of_respondent'] == 'Female').astype(int)

print("✅ Feature engineering complete")

# ============================================================================
# STEP 5: SIMPLE PREPROCESSING (IMPROVEMENT 2 - No Data Leakage)
# ============================================================================

def simple_preprocessing(data, is_train=True):
    """
    Simple preprocessing that keeps column names and avoids data leakage.
    """
    data = data.copy()

    # Drop columns we don't need
    # Added 'location_type', 'cellphone_access', 'gender_of_respondent' to drop_cols
    drop_cols = ['uniqueid', 'year', 'location_type', 'cellphone_access', 'gender_of_respondent']
    data = data.drop([col for col in drop_cols if col in data.columns], axis=1)

    # Select columns for one-hot encoding
    onehot_cols = ['relationship_with_head', 'marital_status', 'education_level', 'job_type', 'country']

    # Filter to only columns that exist
    onehot_cols = [col for col in onehot_cols if col in data.columns]

    # Apply one-hot encoding
    data = pd.get_dummies(data, columns=onehot_cols, drop_first=False)

    # List of columns to scale
    scale_cols = ['household_size', 'age_of_respondent', 'education_numeric', 'age_group', 'household_group']
    scale_cols = [col for col in scale_cols if col in data.columns]

    # Scale numerical columns
    if len(scale_cols) > 0:
        scaler = MinMaxScaler(feature_range=(0, 1))
        data[scale_cols] = scaler.fit_transform(data[scale_cols])

    return data

# ============================================================================
# STEP 6: SEPARATE FEATURES AND TARGET
# ============================================================================
# Remove target from features
X = train.drop('bank_account', axis=1)
y = train['bank_account']

print(f"\nFeatures shape: {X.shape}")
print(f"Target shape: {y.shape}")

# ============================================================================
# STEP 7: PREPROCESS (ONCE FOR ALL DATA - NO LEAKAGE)
# ============================================================================
print("\n🔄 Preprocessing data...")
X_processed = simple_preprocessing(X)
test_processed = simple_preprocessing(test, is_train=False)

# Make sure test has same columns as train
for col in X_processed.columns:
    if col not in test_processed.columns:
        test_processed[col] = 0
test_processed = test_processed[X_processed.columns]

print(f"After preprocessing: {X_processed.shape[1]} features")

# ============================================================================
# STEP 8: SPLIT DATA (CORRECTLY - AFTER PREPROCESSING)
# ============================================================================
X_train, X_val, y_train, y_val = train_test_split(
    X_processed, y,
    stratify=y,
    test_size=0.2,
    random_state=42
)

print(f"\nTraining set: {X_train.shape[0]} rows")
print(f"Validation set: {X_val.shape[0]} rows")

# ============================================================================
# STEP 9: TRAIN XGBOOST WITH BEST PARAMETERS
# ============================================================================
print("\n🔄 Training XGBoost model...")

xgb_model = XGBClassifier(
    min_child_weight=4,
    gamma=1,
    subsample=0.9,
    max_depth=4,
    n_estimators=200,
    learning_rate=0.05,
    eval_metric='logloss',
    random_state=42
)

xgb_model.fit(X_train, y_train)

# ============================================================================
# STEP 10: EVALUATE MODEL
# ============================================================================
# Predictions
y_pred = xgb_model.predict(X_val)

# Accuracy
acc = accuracy_score(y_val, y_pred)
print(f"\n📊 MODEL PERFORMANCE")
print(f"Accuracy: {acc:.4f}")
print(f"Error Rate: {1 - acc:.4f}")

# Detailed report
print(f"\n📊 CLASSIFICATION REPORT")
print(classification_report(y_val, y_pred, target_names=['No Bank', 'Has Bank']))

# Confusion Matrix
cm = confusion_matrix(y_val, y_pred)
print(f"\n📊 CONFUSION MATRIX")
print(f"True Negatives: {cm[0][0]:,}")
print(f"False Positives: {cm[0][1]:,}")
print(f"False Negatives: {cm[1][0]:,}")
print(f"True Positives: {cm[1][1]:,}")

# ============================================================================
# STEP 11: FEATURE IMPORTANCE
# ============================================================================
print(f"\n📊 TOP 10 MOST IMPORTANT FEATURES")
feature_importance = pd.DataFrame({
    'feature': X_train.columns,
    'importance': xgb_model.feature_importances_
}).sort_values('importance', ascending=False)

for i, row in feature_importance.head(10).iterrows():
    print(f"   {row['feature']:<40s}: {row['importance']:.4f}")

# ============================================================================
# STEP 12: PREDICT ON TEST DATA
# ============================================================================
test_predictions = xgb_model.predict(test_processed)

# ============================================================================
# STEP 13: CREATE SUBMISSION
# ============================================================================
# Convert predictions back to 'Yes'/'No'
test_predictions_label = le.inverse_transform(test_predictions)

submission = pd.DataFrame({
    "uniqueid": test_uniqueid + " x " + test['country'],
    "bank_account": test_predictions_label
})

submission.to_csv('1submission.csv', index=False)
print(f"\n✅ Submission saved as '1submission.csv'")
# Out:
# ✅ Feature engineering complete
#
# Features shape: (23524, 18)
# Target shape: (23524,)
#
# 🔄 Preprocessing data...
# After preprocessing: 39 features
#
# Training set: 18819 rows
# Validation set: 4705 rows
#
# 🔄 Training XGBoost model...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2379/3264968177.py in <cell line: 0>()
#     122 print("\n🔄 Training XGBoost model...")
#     123
# --> 124 xgb_model = XGBClassifier(
#     125     min_child_weight=4,
#     126     gamma=1,
#
# NameError: name 'XGBClassifier' is not defined

# %%
# ============================================================================
# LIGHTGBM MODEL ONLY
# ============================================================================
from lightgbm import LGBMClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

print("=" * 80)
print("LIGHTGBM MODEL")
print("=" * 80)

# Create LightGBM model
lgb_model = LGBMClassifier(
    num_leaves=31,
    max_depth=5,
    learning_rate=0.05,
    n_estimators=200,
    random_state=42,
    verbose=-1
)

# Train model
print("\n🔄 Training LightGBM...")
lgb_model.fit(X_train, y_train)

# Predict on validation
y_pred = lgb_model.predict(X_val)

# Calculate accuracy
acc = accuracy_score(y_val, y_pred)
error = 1 - acc

print(f"\n📊 MODEL PERFORMANCE")
print(f"Accuracy:   {acc:.4f}")
print(f"Error Rate: {error:.4f}")

# Classification report
print(f"\n📊 CLASSIFICATION REPORT")
print(classification_report(y_val, y_pred, target_names=['No Bank', 'Has Bank']))

# Confusion matrix
cm = confusion_matrix(y_val, y_pred)
print(f"\n📊 CONFUSION MATRIX")
print(f"True Negatives:  {cm[0][0]:,}")
print(f"False Positives: {cm[0][1]:,}")
print(f"False Negatives: {cm[1][0]:,}")
print(f"True Positives:  {cm[1][1]:,}")

# Feature importance
print(f"\n📊 TOP 10 IMPORTANT FEATURES")
feature_importance = pd.DataFrame({
    'feature': X_train.columns,
    'importance': lgb_model.feature_importances_
}).sort_values('importance', ascending=False)

for i, row in feature_importance.head(10).iterrows():
    print(f"   {row['feature']:<40s}: {row['importance']:.4f}")

# Predict on test data
print(f"\n🔄 Predicting on test data...")
test_predictions = lgb_model.predict(test_processed)

# Convert to Yes/No
test_predictions_label = le.inverse_transform(test_predictions)

# Create submission
submission = pd.DataFrame({
    "uniqueid": test_uniqueid + " x " + test['country'],
    "bank_account": test_predictions_label
})

submission.to_csv('2submission.csv', index=False)
print(f"\n✅ Submission saved as '2submission.csv'")
# Out:
# ...
# LIGHTGBM MODEL
# ...
#
# 🔄 Training LightGBM...
#
# 📊 MODEL PERFORMANCE
# Accuracy:   0.8905
# Error Rate: 0.1095
#
# 📊 CLASSIFICATION REPORT
#               precision    recall  f1-score   support
#
#      No Bank       0.91      0.97      0.94      4043
#     Has Bank       0.71      0.38      0.49       662
#
#     accuracy                           0.89      4705
#    macro avg       0.81      0.68      0.72      4705
# weighted avg       0.88      0.89      0.88      4705
#
#
# 📊 CONFUSION MATRIX
# True Negatives:  3,939
# False Positives: 104
# False Negatives: 411
# True Positives:  251
#
# 📊 TOP 10 IMPORTANT FEATURES
#    age_of_respondent                       : 1138.0000
#    household_size                          : 503.0000
#    education_numeric                       : 417.0000
#    is_urban                                : 305.0000
#    is_female                               : 251.0000
#    has_cellphone                           : 202.0000
# ...

# %%
files.download('2submission.csv')

# %%
# ============================================================================
# RANDOM FOREST MODEL ONLY
# ============================================================================
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

print("=" * 80)
print("RANDOM FOREST MODEL")
print("=" * 80)

# Create Random Forest model
rf_model = RandomForestClassifier(
    n_estimators=300,
    max_depth=15,
    min_samples_split=10,
    min_samples_leaf=5,
    random_state=42,
    n_jobs=-1
)

# Train model
print("\n🔄 Training Random Forest...")
rf_model.fit(X_train, y_train)

# Predict on validation
y_pred = rf_model.predict(X_val)

# Calculate accuracy
acc = accuracy_score(y_val, y_pred)
error = 1 - acc

print(f"\n📊 MODEL PERFORMANCE")
print(f"Accuracy:   {acc:.4f}")
print(f"Error Rate: {error:.4f}")

# Classification report
print(f"\n📊 CLASSIFICATION REPORT")
print(classification_report(y_val, y_pred, target_names=['No Bank', 'Has Bank']))

# Confusion matrix
cm = confusion_matrix(y_val, y_pred)
print(f"\n📊 CONFUSION MATRIX")
print(f"True Negatives:  {cm[0][0]:,}")
print(f"False Positives: {cm[0][1]:,}")
print(f"False Negatives: {cm[1][0]:,}")
print(f"True Positives:  {cm[1][1]:,}")

# Feature importance
print(f"\n📊 TOP 10 IMPORTANT FEATURES")
feature_importance = pd.DataFrame({
    'feature': X_train.columns,
    'importance': rf_model.feature_importances_
}).sort_values('importance', ascending=False)

for i, row in feature_importance.head(10).iterrows():
    print(f"   {row['feature']:<40s}: {row['importance']:.4f}")

# Predict on test data
print(f"\n🔄 Predicting on test data...")
test_predictions = rf_model.predict(test_processed)

# Convert to Yes/No
test_predictions_label = le.inverse_transform(test_predictions)

# Create submission
submission = pd.DataFrame({
    "uniqueid": test_uniqueid + " x " + test['country'],
    "bank_account": test_predictions_label
})

submission.to_csv('submission.csv', index=False)
print(f"\n✅ Submission saved as 'submission.csv'")
# Out:
# ...
# RANDOM FOREST MODEL
# ...
#
# 🔄 Training Random Forest...
#
# 📊 MODEL PERFORMANCE
# Accuracy:   0.8897
# Error Rate: 0.1103
#
# 📊 CLASSIFICATION REPORT
#               precision    recall  f1-score   support
#
#      No Bank       0.90      0.98      0.94      4043
#     Has Bank       0.72      0.35      0.47       662
#
#     accuracy                           0.89      4705
#    macro avg       0.81      0.66      0.71      4705
# weighted avg       0.88      0.89      0.87      4705
#
#
# 📊 CONFUSION MATRIX
# True Negatives:  3,954
# False Positives: 89
# False Negatives: 430
# True Positives:  232
#
# 📊 TOP 10 IMPORTANT FEATURES
#    education_numeric                       : 0.1627
#    age_of_respondent                       : 0.0917
#    job_type_Formally employed Private      : 0.0756
#    job_type_Formally employed Government   : 0.0691
#    education_level_Vocational/Specialised training: 0.0539
#    has_cellphone                           : 0.0509
# ...

# %%
# ============================================================================
# VOTING ENSEMBLE MODEL
# ============================================================================
from sklearn.ensemble import VotingClassifier, RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

print("=" * 80)
print("VOTING ENSEMBLE MODEL")
print("=" * 80)

# Create Voting Ensemble (combines multiple models)
voting_model = VotingClassifier(
    estimators=[
        ('xgb', XGBClassifier(
            n_estimators=200,
            max_depth=4,
            learning_rate=0.05,
            subsample=0.8,
            colsample_bytree=0.8,
            eval_metric='logloss',
            random_state=42
        )),
        ('lgb', LGBMClassifier(
            n_estimators=200,
            max_depth=5,
            learning_rate=0.05,
            num_leaves=31,
            random_state=42,
            verbose=-1
        )),
        ('rf', RandomForestClassifier(
            n_estimators=200,
            max_depth=10,
            min_samples_split=10,
            min_samples_leaf=5,
            random_state=42,
            n_jobs=-1
        )),
        ('gb', GradientBoostingClassifier(
            n_estimators=200,
            max_depth=5,
            learning_rate=0.05,
            subsample=0.8,
            random_state=42
        ))
    ],
    voting='soft'  # Uses probabilities for better accuracy
)

# Train model
print("\n🔄 Training Voting Ensemble...")
voting_model.fit(X_train, y_train)

# Predict on validation
y_pred = voting_model.predict(X_val)

# Calculate accuracy
acc = accuracy_score(y_val, y_pred)
error = 1 - acc

print(f"\n📊 MODEL PERFORMANCE")
print(f"Accuracy:   {acc:.4f}")
print(f"Error Rate: {error:.4f}")

# Classification report
print(f"\n📊 CLASSIFICATION REPORT")
print(classification_report(y_val, y_pred, target_names=['No Bank', 'Has Bank']))

# Confusion matrix
cm = confusion_matrix(y_val, y_pred)
print(f"\n📊 CONFUSION MATRIX")
print(f"True Negatives:  {cm[0][0]:,}")
print(f"False Positives: {cm[0][1]:,}")
print(f"False Negatives: {cm[1][0]:,}")
print(f"True Positives:  {cm[1][1]:,}")

# Show individual model performance
print(f"\n📊 INDIVIDUAL MODEL PERFORMANCE")
for name, model in voting_model.named_estimators_.items():
    y_ind_pred = model.predict(X_val)
    ind_acc = accuracy_score(y_val, y_ind_pred)
    print(f"   {name:<10s}: Accuracy = {ind_acc:.4f} | Error = {1-ind_acc:.4f}")

# Predict on test data
print(f"\n🔄 Predicting on test data...")
test_predictions = voting_model.predict(test_processed)

# Convert to Yes/No
test_predictions_label = le.inverse_transform(test_predictions)

# Create submission
submission = pd.DataFrame({
    "uniqueid": test_uniqueid + " x " + test['country'],
    "bank_account": test_predictions_label
})

submission.to_csv('submission.csv', index=False)
print(f"\n✅ Submission saved as 'submission.csv'")
# Out:
# ...
# VOTING ENSEMBLE MODEL
# ...
#
# 🔄 Training Voting Ensemble...
#
# 📊 MODEL PERFORMANCE
# Accuracy:   0.8920
# Error Rate: 0.1080
#
# 📊 CLASSIFICATION REPORT
#               precision    recall  f1-score   support
#
#      No Bank       0.90      0.98      0.94      4043
#     Has Bank       0.73      0.37      0.49       662
#
#     accuracy                           0.89      4705
#    macro avg       0.82      0.67      0.71      4705
# weighted avg       0.88      0.89      0.88      4705
#
#
# 📊 CONFUSION MATRIX
# True Negatives:  3,954
# False Positives: 89
# False Negatives: 419
# True Positives:  243
#
# 📊 INDIVIDUAL MODEL PERFORMANCE
#    xgb       : Accuracy = 0.8903 | Error = 0.1097
#    lgb       : Accuracy = 0.8905 | Error = 0.1095
#    rf        : Accuracy = 0.8886 | Error = 0.1114
#    gb        : Accuracy = 0.8886 | Error = 0.1114
#
# 🔄 Predicting on test data...
#
# ✅ Submission saved as 'submission.csv'

# %%
files.download('submission.csv')

# %%
files.download('2submission.csv')

# %%
# Check class distribution
print("=" * 50)
print("CLASS DISTRIBUTION CHECK")
print("=" * 50)

# Check training data
train_counts = y_train.value_counts()
print(f"\nTraining Data:")
print(f"   Class 0 (No Bank):  {train_counts[0]:,} ({train_counts[0]/len(y_train)*100:.1f}%)")
print(f"   Class 1 (Has Bank): {train_counts[1]:,} ({train_counts[1]/len(y_train)*100:.1f}%)")

# Check original data
original_counts = train['bank_account'].value_counts()
print(f"\nOriginal Data:")
print(f"   Class 0 (No Bank):  {original_counts[0]:,} ({original_counts[0]/len(train)*100:.1f}%)")
print(f"   Class 1 (Has Bank): {original_counts[1]:,} ({original_counts[1]/len(train)*100:.1f}%)")

# Check validation predictions
y_pred = voting_model.predict(X_val)
pred_counts = pd.Series(y_pred).value_counts()
print(f"\nValidation Predictions:")
print(f"   Class 0 (No Bank):  {pred_counts.get(0, 0):,}")
print(f"   Class 1 (Has Bank): {pred_counts.get(1, 0):,}")

# Check if model is biased toward one class
print(f"\n⚠️  DIAGNOSIS:")
if pred_counts.get(1, 0) == 0:
    print("   CRITICAL: Model predicting ALL zeros (complete failure)")
elif pred_counts.get(0, 0) / len(y_pred) > 0.90:
    print("   WARNING: Model heavily biased toward class 0 (needs balancing)")
elif pred_counts.get(1, 0) / len(y_pred) > 0.90:
    print("   WARNING: Model heavily biased toward class 1 (needs balancing)")
else:
    print("   Model predictions are reasonably balanced")
# Out:
# ...
# CLASS DISTRIBUTION CHECK
# ...
#
# Training Data:
#    Class 0 (No Bank):  16,169 (85.9%)
#    Class 1 (Has Bank): 2,650 (14.1%)
#
# Original Data:
#    Class 0 (No Bank):  20,212 (85.9%)
#    Class 1 (Has Bank): 3,312 (14.1%)
#
# Validation Predictions:
#    Class 0 (No Bank):  4,373
#    Class 1 (Has Bank): 332
#
# ⚠️  DIAGNOSIS:
#    WARNING: Model heavily biased toward class 0 (needs balancing)

# %%
# ============================================================================
# VOTING ENSEMBLE WITH CLASS WEIGHTS (Fixes Imbalance)
# ============================================================================
from sklearn.ensemble import VotingClassifier, RandomForestClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

print("=" * 80)
print("VOTING ENSEMBLE WITH CLASS BALANCING")
print("=" * 80)

# Calculate class weight
# This tells the model to pay more attention to the minority class
class_weight_ratio = (y_train == 0).sum() / (y_train == 1).sum()
print(f"\nClass weight ratio: {class_weight_ratio:.2f}")
print(f"(Model will weight minority class {class_weight_ratio:.2f}x more)\n")

# Create models with class balancing
voting_model = VotingClassifier(
    estimators=[
        ('xgb', XGBClassifier(
            n_estimators=200,
            max_depth=4,
            learning_rate=0.05,
            subsample=0.8,
            colsample_bytree=0.8,
            scale_pos_weight=class_weight_ratio,  # ✅ THIS FIXES IMBALANCE
            eval_metric='logloss',
            random_state=42
        )),
        ('lgb', LGBMClassifier(
            n_estimators=200,
            max_depth=5,
            learning_rate=0.05,
            num_leaves=31,
            class_weight='balanced',  # ✅ THIS FIXES IMBALANCE
            random_state=42,
            verbose=-1
        )),
        ('rf', RandomForestClassifier(
            n_estimators=200,
            max_depth=10,
            min_samples_split=10,
            min_samples_leaf=5,
            class_weight='balanced',  # ✅ THIS FIXES IMBALANCE
            random_state=42,
            n_jobs=-1
        )),
        ('gb', GradientBoostingClassifier(
            n_estimators=200,
            max_depth=5,
            learning_rate=0.05,
            subsample=0.8,
            random_state=42
        ))
    ],
    voting='soft'
)

# Train model
print("🔄 Training Voting Ensemble...")
voting_model.fit(X_train, y_train)

# Predict
y_pred = voting_model.predict(X_val)

# Results
acc = accuracy_score(y_val, y_pred)
error = 1 - acc

print(f"\n📊 MODEL PERFORMANCE")
print(f"Accuracy:   {acc:.4f}")
print(f"Error Rate: {error:.4f}")

print(f"\n📊 CLASSIFICATION REPORT")
print(classification_report(y_val, y_pred, target_names=['No Bank', 'Has Bank']))

cm = confusion_matrix(y_val, y_pred)
print(f"\n📊 CONFUSION MATRIX")
print(f"True Negatives:  {cm[0][0]:,}")
print(f"False Positives: {cm[0][1]:,}")
print(f"False Negatives: {cm[1][0]:,}")
print(f"True Positives:  {cm[1][1]:,}")

# Predict on test data
test_predictions = voting_model.predict(test_processed)
test_predictions_label = le.inverse_transform(test_predictions)

submission = pd.DataFrame({
    "uniqueid": test_uniqueid + " x " + test['country'],
    "bank_account": test_predictions_label
})
submission.to_csv('submission.csv', index=False)
print(f"\n✅ Submission saved as 'submission.csv'")
# Out:
# ...
# VOTING ENSEMBLE WITH CLASS BALANCING
# ...
#
# Class weight ratio: 6.10
# (Model will weight minority class 6.10x more)
#
# 🔄 Training Voting Ensemble...
#
# 📊 MODEL PERFORMANCE
# Accuracy:   0.8461
# Error Rate: 0.1539
#
# 📊 CLASSIFICATION REPORT
#               precision    recall  f1-score   support
#
#      No Bank       0.94      0.87      0.91      4043
#     Has Bank       0.47      0.68      0.55       662
#
#     accuracy                           0.85      4705
#    macro avg       0.71      0.78      0.73      4705
# weighted avg       0.88      0.85      0.86      4705
#
#
# 📊 CONFUSION MATRIX
# True Negatives:  3,533
# False Positives: 510
# False Negatives: 214
# True Positives:  448
#
# ✅ Submission saved as 'submission.csv'

# %%
# ============================================================================
# COMPARE BEFORE vs AFTER
# ============================================================================
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

print("=" * 60)
print("MODEL DIAGNOSIS")
print("=" * 60)

y_pred = voting_model.predict(X_val)

# Calculate all metrics (not just accuracy)
acc = accuracy_score(y_val, y_pred)
prec = precision_score(y_val, y_pred)
rec = recall_score(y_val, y_pred)
f1 = f1_score(y_val, y_pred)

print(f"""
📊 COMPLETE METRICS:
   Accuracy:  {acc:.4f}  (can be misleading with imbalance)
   Precision: {prec:.4f}  (when we say Yes, how often correct?)
   Recall:    {rec:.4f}  (what % of actual Yes did we find?)
   F1 Score:  {f1:.4f}  (balance of Precision & Recall) ← MOST IMPORTANT
""")

# Confusion matrix
cm = confusion_matrix(y_val, y_pred)
print(f"""
📊 CONFUSION MATRIX:
                    Predicted No   Predicted Yes
   Actual No          {cm[0][0]:>10,}    {cm[0][1]:>10,}
   Actual Yes         {cm[1][0]:>10,}    {cm[1][1]:>10,}
""")

# THE REAL TEST
print("=" * 60)
print("DIAGNOSIS")
print("=" * 60)

if rec < 0.3:
    print("❌ BAD: Model finding less than 30% of people with bank accounts")
    print("   → Try: More class weight, different model")
elif rec < 0.5:
    print("⚠️  OK: Model finding some bank account holders")
    print("   → Try: Adjust class_weight higher")
elif rec < 0.7:
    print("✅ GOOD: Model finding most bank account holders")
    print("   → This is a usable model!")
else:
    print("🎉 GREAT: Model finding almost all bank account holders")
    print("   → Your model is excellent!")

# Check what matters for YOUR problem
print(f"""
🎯 WHAT MATTERS FOR YOUR PROBLEM:

   If you want to FIND unbanked people to help them:
   → Focus on RECALL for class 1 (Has Bank)
   → Or RECALL for class 0 (No Bank)

   If you want to be RIGHT when you predict:
   → Focus on PRECISION

   Best overall metric for imbalanced data:
   → F1 SCORE = {f1:.4f}
""")
# Out:
# ...
# MODEL DIAGNOSIS
# ...
#
# 📊 COMPLETE METRICS:
#    Accuracy:  0.8461  (can be misleading with imbalance)
#    Precision: 0.4676  (when we say Yes, how often correct?)
#    Recall:    0.6767  (what % of actual Yes did we find?)
#    F1 Score:  0.5531  (balance of Precision & Recall) ← MOST IMPORTANT
#
#
# 📊 CONFUSION MATRIX:
#                     Predicted No   Predicted Yes
#    Actual No               3,533           510
#    Actual Yes                214           448
#
# ...
# DIAGNOSIS
# ...
# ✅ GOOD: Model finding most bank account holders
#    → This is a usable model!
#
# 🎯 WHAT MATTERS FOR YOUR PROBLEM:
#
#    If you want to FIND unbanked people to help them:
#    → Focus on RECALL for class 1 (Has Bank)
#    → Or RECALL for class 0 (No Bank)
#
#    If you want to be RIGHT when you predict:
#    → Focus on PRECISION
#
#    Best overall metric for imbalanced data:
#    → F1 SCORE = 0.5531

# %%
# Try different class weights to find sweet spot
from sklearn.ensemble import RandomForestClassifier

for weight in ['balanced', {0:1, 1:2}, {0:1, 1:3}, {0:1, 1:5}]:
    rf = RandomForestClassifier(
        n_estimators=200,
        max_depth=10,
        class_weight=weight,
        random_state=42,
        n_jobs=-1
    )
    rf.fit(X_train, y_train)
    y_pred = rf.predict(X_val)

    f1 = f1_score(y_val, y_pred)
    acc = accuracy_score(y_val, y_pred)
    rec = recall_score(y_val, y_pred)

    print(f"Weight {str(weight):<20s} | Acc: {acc:.4f} | F1: {f1:.4f} | Recall: {rec:.4f}")
# Out:
# Weight balanced             | Acc: 0.8108 | F1: 0.5271 | Recall: 0.7492
# Weight {0: 1, 1: 2}         | Acc: 0.8840 | F1: 0.5357 | Recall: 0.4758
# Weight {0: 1, 1: 3}         | Acc: 0.8689 | F1: 0.5545 | Recall: 0.5801
# Weight {0: 1, 1: 5}         | Acc: 0.8395 | F1: 0.5460 | Recall: 0.6858

# %%
# ============================================================================
# CATBOOST MODEL (Handles imbalance automatically)
# ============================================================================
# !pip install catboost
from catboost import CatBoostClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report

print("=" * 80)
print("CATBOOST MODEL")
print("=" * 80)

# Check class balance
class_ratio = (y_train == 0).sum() / (y_train == 1).sum()
print(f"\nClass ratio (No/Yes): {class_ratio:.2f}")

# Create CatBoost model
cat_model = CatBoostClassifier(
    iterations=500,
    depth=6,
    learning_rate=0.05,
    l2_leaf_reg=3,
    border_count=128,
    scale_pos_weight=class_ratio,  # ✅ Handles imbalance
    eval_metric='F1',              # ✅ Optimizes F1 not accuracy
    random_seed=42,
    verbose=100                    # Show progress every 100 iterations
)

# Train model
print("\n🔄 Training CatBoost...")
cat_model.fit(
    X_train, y_train,
    eval_set=(X_val, y_val),
    early_stopping_rounds=50,      # Stop if no improvement
    verbose=False
)

# Predict on validation
y_pred = cat_model.predict(X_val)

# Calculate ALL metrics
acc = accuracy_score(y_val, y_pred)
prec = precision_score(y_val, y_pred)
rec = recall_score(y_val, y_pred)
f1 = f1_score(y_val, y_pred)
error = 1 - acc

print(f"\n📊 MODEL PERFORMANCE")
print(f"Accuracy:   {acc:.4f}")
print(f"Precision:  {prec:.4f}")
print(f"Recall:     {rec:.4f}")
print(f"F1 Score:   {f1:.4f}")
print(f"Error Rate: {error:.4f}")

print(f"\n📊 CLASSIFICATION REPORT")
print(classification_report(y_val, y_pred, target_names=['No Bank', 'Has Bank']))

cm = confusion_matrix(y_val, y_pred)
print(f"\n📊 CONFUSION MATRIX")
print(f"True Negatives:  {cm[0][0]:,}")
print(f"False Positives: {cm[0][1]:,}")
print(f"False Negatives: {cm[1][0]:,}")
print(f"True Positives:  {cm[1][1]:,}")

# Feature importance
print(f"\n📊 TOP 10 IMPORTANT FEATURES")
feature_importance = pd.DataFrame({
    'feature': X_train.columns,
    'importance': cat_model.feature_importances_
}).sort_values('importance', ascending=False)

for i, row in feature_importance.head(10).iterrows():
    print(f"   {row['feature']:<40s}: {row['importance']:.4f}")

# Predict on test data
print(f"\n🔄 Predicting on test data...")
test_predictions = cat_model.predict(test_processed)

# Convert to Yes/No
test_predictions_label = le.inverse_transform(test_predictions)

# Create submission
submission = pd.DataFrame({
    "uniqueid": test_uniqueid + " x " + test['country'],
    "bank_account": test_predictions_label
})

submission.to_csv('submission.csv', index=False)
print(f"\n✅ Submission saved as 'submission.csv'")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.1/97.1 MB 5.7 MB/s eta 0:00:00
# ...
# CATBOOST MODEL
# ...
#
# Class ratio (No/Yes): 6.10
#
# 🔄 Training CatBoost...
#
# 📊 MODEL PERFORMANCE
# Accuracy:   0.7887
# Precision:  0.3799
# Recall:     0.7931
# F1 Score:   0.5137
# Error Rate: 0.2113
#
# 📊 CLASSIFICATION REPORT
#               precision    recall  f1-score   support
#
#      No Bank       0.96      0.79      0.87      4043
#     Has Bank       0.38      0.79      0.51       662
#
#     accuracy                           0.79      4705
#    macro avg       0.67      0.79      0.69      4705
# weighted avg       0.88      0.79      0.82      4705
#
#
# 📊 CONFUSION MATRIX
# True Negatives:  3,186
# False Positives: 857
# False Negatives: 137
# True Positives:  525
#
# 📊 TOP 10 IMPORTANT FEATURES
#    education_numeric                       : 21.0716
#    has_cellphone                           : 19.5036
#    age_of_respondent                       : 6.9585
# ...

# %%
# ============================================================================
# IMPORTS
# ============================================================================
# !pip install catboost
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import mean_absolute_error
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
import warnings
warnings.filterwarnings('ignore')

# ============================================================================
# LOAD DATA
# ============================================================================
train = pd.read_csv('./Train.csv')
test = pd.read_csv('./Test.csv')
ss = pd.read_csv('./SampleSubmission.csv')

# Save test IDs
test_uniqueid = test['uniqueid']

# Encode target
le = LabelEncoder()
train['bank_account'] = le.fit_transform(train['bank_account'])

print(f"Train shape: {train.shape}")
print(f"Test shape: {test.shape}")
print(f"Target distribution:\n{train['bank_account'].value_counts(normalize=True)}")

# ============================================================================
# FEATURE ENGINEERING
# ============================================================================
def engineer_features(df):
    df = df.copy()

    # 1. EDUCATION NUMERIC
    edu_map = {
        'No formal education': 0,
        'Primary education': 1,
        'Secondary education': 2,
        'Vocational/Specialised training': 3,
        'Tertiary education': 4,
        'Other/Dont know/RTA': 0
    }
    df['edu_numeric'] = df['education_level'].map(edu_map)

    # 2. BINARY FLAGS
    df['is_urban'] = (df['location_type'] == 'Urban').astype(int)
    df['has_cellphone'] = (df['cellphone_access'] == 'Yes').astype(int)
    df['is_female'] = (df['gender_of_respondent'] == 'Female').astype(int)
    df['is_married'] = (df['marital_status'] == 'Married/Living together').astype(int)
    df['is_head'] = (df['relationship_with_head'] == 'Head of Household').astype(int)

    # 3. FORMAL JOB FLAG
    formal_jobs = ['Formally employed Government', 'Formally employed Private']
    df['has_formal_job'] = df['job_type'].isin(formal_jobs).astype(int)

    # 4. BINNING
    df['age_group'] = pd.cut(df['age_of_respondent'],
                              bins=[0, 18, 25, 35, 50, 65, 120],
                              labels=[0, 1, 2, 3, 4, 5]).astype(int)

    df['household_group'] = pd.cut(df['household_size'],
                                    bins=[0, 1, 3, 6, 10, 50],
                                    labels=[0, 1, 2, 3, 4]).astype(int)

    # 5. RISK SCORE
    df['risk_score'] = 0
    df.loc[df['is_urban'] == 0, 'risk_score'] += 2
    df.loc[df['edu_numeric'] <= 1, 'risk_score'] += 2
    df.loc[df['has_cellphone'] == 0, 'risk_score'] += 1
    df.loc[df['is_female'] == 1, 'risk_score'] += 1
    df.loc[df['has_formal_job'] == 0, 'risk_score'] += 1

    # 6. INTERACTIONS (MOST IMPORTANT)
    df['edu_x_job'] = df['edu_numeric'] * df['has_formal_job']
    df['edu_x_urban'] = df['edu_numeric'] * df['is_urban']
    df['cell_x_urban'] = df['has_cellphone'] * df['is_urban']
    df['edu_x_cell'] = df['edu_numeric'] * df['has_cellphone']
    df['age_x_edu'] = df['age_of_respondent'] * df['edu_numeric']
    df['urban_x_job'] = df['is_urban'] * df['has_formal_job']

    # 7. RATIOS
    df['dependency_ratio'] = df['household_size'] / (df['age_of_respondent'] + 1)

    # 8. COUNTRY-SPECIFIC FEATURES
    # Create country dummy variables before one-hot encoding
    for country in df['country'].unique():
        df[f'country_{country}'] = (df['country'] == country).astype(int)

    # Country × Education interactions
    df['kenya_x_edu'] = df['country_Kenya'] * df['edu_numeric']
    df['rwanda_x_edu'] = df['country_Rwanda'] * df['edu_numeric']

    return df

# Apply feature engineering
print("\n🔧 Engineering features...")
train = engineer_features(train)
test = engineer_features(test)

# ============================================================================
# PREPROCESSING
# ============================================================================
def preprocess(df, is_train=True):
    df = df.copy()

    # Drop unnecessary columns
    drop_cols = ['uniqueid', 'year', 'country', 'education_level', 'job_type',
                 'marital_status', 'relationship_with_head', 'location_type',
                 'cellphone_access', 'gender_of_respondent']

    if 'bank_account' in df.columns:
        target = df['bank_account']
        df = df.drop('bank_account', axis=1)
    else:
        target = None

    df = df.drop([c for c in drop_cols if c in df.columns], axis=1)

    # Scale numerical features
    scaler = MinMaxScaler()
    num_cols = df.select_dtypes(include=['int64', 'float64']).columns
    df[num_cols] = scaler.fit_transform(df[num_cols])

    if target is not None:
        return df, target
    return df

X_train, y_train = preprocess(train, is_train=True)
X_test = preprocess(test, is_train=False)

print(f"\n✅ Preprocessing complete")
print(f"   Train features: {X_train.shape[1]}")
print(f"   Test features: {X_test.shape[1]}")

# ============================================================================
# MODEL TRAINING WITH CROSS-VALIDATION
# ============================================================================
print("\n🔄 Training models with 5-Fold Cross-Validation...")

# Class ratio for balancing
class_ratio = (y_train == 0).sum() / (y_train == 1).sum()

# Initialize models
models = {
    'CatBoost': CatBoostClassifier(
        iterations=500, depth=6, learning_rate=0.05,
        scale_pos_weight=class_ratio, verbose=0, random_seed=42
    ),
    'LightGBM': LGBMClassifier(
        n_estimators=500, max_depth=6, learning_rate=0.05,
        class_weight='balanced', verbose=-1, random_state=42
    )
}

# Cross-validation
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

val_probs = {name: np.zeros(len(X_train)) for name in models}
test_probs_all = {name: np.zeros(len(X_test)) for name in models}
fold_mae = {name: [] for name in models}

for fold, (train_idx, val_idx) in enumerate(skf.split(X_train, y_train)):
    X_tr, X_vl = X_train.iloc[train_idx], X_train.iloc[val_idx]
    y_tr, y_vl = y_train.iloc[train_idx], y_train.iloc[val_idx]

    for name, model in models.items():
        # Train
        model.fit(X_tr, y_tr)

        # Predict probabilities
        val_pred = model.predict_proba(X_vl)[:, 1]
        test_pred = model.predict_proba(X_test)[:, 1]

        # Store
        val_probs[name][val_idx] = val_pred
        test_probs_all[name] += test_pred / skf.n_splits

        # MAE
        mae = mean_absolute_error(y_vl, val_pred)
        fold_mae[name].append(mae)

    print(f"   Fold {fold+1} complete")

# Print results
print(f"\n📊 CROSS-VALIDATION RESULTS")
print(f"{'='*50}")
for name in models:
    avg_mae = np.mean(fold_mae[name])
    std_mae = np.std(fold_mae[name])
    print(f"{name:<15s}: MAE = {avg_mae:.5f} (+/- {std_mae:.5f})")
    print(f"            Fold MAEs: {[f'{m:.5f}' for m in fold_mae[name]]}")

# ============================================================================
# ENSEMBLE
# ============================================================================
print(f"\n🔄 Creating ensemble...")

# Average probabilities from all models
final_val_probs = np.mean([val_probs[name] for name in models], axis=0)
final_test_probs = np.mean([test_probs_all[name] for name in models], axis=0)

ensemble_mae = mean_absolute_error(y_train, final_val_probs)
print(f"\n📊 ENSEMBLE PERFORMANCE")
print(f"{'='*50}")
print(f"Ensemble MAE: {ensemble_mae:.5f}")

# Show individual model contribution
print(f"\n📊 INDIVIDUAL MODEL CONTRIBUTION TO ENSEMBLE")
for name in models:
    individual_mae = mean_absolute_error(y_train, val_probs[name])
    print(f"{name:<15s}: MAE = {individual_mae:.5f}")

# ============================================================================
# FINAL SUBMISSION
# ============================================================================
print(f"\n✅ Creating submission file...")

submission = pd.DataFrame({
    "uniqueid": test_uniqueid + " x " + test['country'],
    "bank_account": final_test_probs  # ← PROBABILITIES, not labels!
})

submission.to_csv('submission.csv', index=False)

print(f"""
{'='*60}
🎉 FINAL RESULTS
{'='*60}
   Ensemble MAE:   {ensemble_mae:.5f}
   Best Model:     {min(fold_mae, key=lambda x: np.mean(fold_mae[x]))}

   Expected test MAE: {ensemble_mae:.5f} (±0.005)

   📁 Submission saved: submission.csv
      → Contains PROBABILITIES (0 to 1)
      → NOT hard labels (0/1)
{'='*60}
""")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.1/97.1 MB 8.8 MB/s eta 0:00:00
# ...
# Train shape: (23524, 13)
# Test shape: (10086, 12)
# Target distribution:
# bank_account
# 0    0.859208
# 1    0.140792
# Name: proportion, dtype: float64
#
# 🔧 Engineering features...
#
# ✅ Preprocessing complete
#    Train features: 25
#    Test features: 25
#
# 🔄 Training models with 5-Fold Cross-Validation...
#    Fold 1 complete
#    Fold 2 complete
#    Fold 3 complete
#    Fold 4 complete
#    Fold 5 complete
#
# 📊 CROSS-VALIDATION RESULTS
# ...
# CatBoost       : MAE = 0.28475 (+/- 0.00363)
#             Fold MAEs: ['0.28474', '0.28730', '0.28165', '0.28004', '0.29001']
# LightGBM       : MAE = 0.27480 (+/- 0.00392)
#             Fold MAEs: ['0.27601', '0.27799', '0.27082', '0.26961', '0.27955']
#
# 🔄 Creating ensemble...
#
# 📊 ENSEMBLE PERFORMANCE
# ...
# Ensemble MAE: 0.27977
#
# 📊 INDIVIDUAL MODEL CONTRIBUTION TO ENSEMBLE
# CatBoost       : MAE = 0.28475
# LightGBM       : MAE = 0.27480
#
# ...

# %%
files.download('submission.csv')

# %%
# ================================
# 1. Imports
# ================================
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import LabelEncoder

from xgboost import XGBClassifier

# ================================
# 2. Load Data
# ================================
train = pd.read_csv("Train.csv")
test = pd.read_csv("Test.csv")

# ================================
# 3. Target Encoding (ONLY ONCE)
# ================================
train['bank_account'] = train['bank_account'].map({'Yes': 1, 'No': 0})

# ================================
# 4. Save test IDs before dropping
# ================================
test_ids = test['uniqueid']

# ================================
# 5. Drop ID column
# ================================
train = train.drop(columns=['uniqueid'])
test = test.drop(columns=['uniqueid'])

# ================================
# 6. Encode categorical features
# ================================
cat_cols = [
    'country', 'location_type', 'cellphone_access',
    'gender_of_respondent', 'relationship_with_head',
    'marital_status', 'education_level', 'job_type'
]

for col in cat_cols:
    le = LabelEncoder()
    train[col] = le.fit_transform(train[col])
    test[col] = le.transform(test[col])

# ================================
# 7. Features and Target
# ================================
X = train.drop(columns=['bank_account'])
y = train['bank_account']

# ================================
# 8. Train / Validation Split
# ================================
X_train, X_val, y_train, y_val = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# ================================
# 9. XGBoost Model (Tuned for MAE)
# ================================
model = XGBClassifier(
    n_estimators=500,
    max_depth=6,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    objective='binary:logistic',
    eval_metric='logloss',   # still OK, we evaluate MAE ourselves
    random_state=42,
    use_label_encoder=False
)

# ================================
# 10. Train Model
# ================================
model.fit(
    X_train, y_train,
    eval_set=[(X_val, y_val)],
    verbose=False
)

# ================================
# 11. Predict Probabilities
# ================================
y_pred_proba = model.predict_proba(X_val)[:, 1]

# ================================
# 12. Evaluate MAE
# ================================
mae = mean_absolute_error(y_val, y_pred_proba)

print("Validation MAE:", mae)

# ================================
# 13. Train on Full Data
# ================================
model.fit(X, y)

# ================================
# 14. Predict on Test Set
# ================================
test_pred = model.predict_proba(test)[:, 1]

# ================================
# 15. Create Submission
# ================================
submission = pd.DataFrame({
    'unique_id': test_ids,
    'bank_account': test_pred
})

submission.to_csv("xgb_submission.csv", index=False)

print("Submission file saved!")
# Out:
# Validation MAE: 0.16214139759540558
# Submission file saved!

# %%
# ============================================================================
# FIXED: LOW MAE PIPELINE
# ============================================================================
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import mean_absolute_error
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
import warnings
warnings.filterwarnings('ignore')

# ============================================================================
# LOAD DATA
# ============================================================================
train = pd.read_csv('./Train.csv')
test = pd.read_csv('./Test.csv')
test_uniqueid = test['uniqueid']

# Encode target
le = LabelEncoder()
train['bank_account'] = le.fit_transform(train['bank_account'])

print(f"Target distribution:\n{train['bank_account'].value_counts(normalize=True)}")

# ============================================================================
# HEAVY FEATURE ENGINEERING (THIS IS WHAT YOU WERE MISSING)
# ============================================================================
def create_features(df):
    df = df.copy()

    # === EDUCATION ===
    edu_map = {
        'No formal education': 0, 'Primary education': 1,
        'Secondary education': 2, 'Vocational/Specialised training': 3,
        'Tertiary education': 4, 'Other/Dont know/RTA': 0
    }
    df['edu_num'] = df['education_level'].map(edu_map)

    # === BINARY FLAGS ===
    df['is_urban'] = (df['location_type'] == 'Urban').astype(int)
    df['has_phone'] = (df['cellphone_access'] == 'Yes').astype(int)
    df['is_female'] = (df['gender_of_respondent'] == 'Female').astype(int)
    df['is_married'] = (df['marital_status'] == 'Married/Living together').astype(int)
    df['is_head'] = (df['relationship_with_head'] == 'Head of Household').astype(int)
    df['is_widowed'] = (df['marital_status'] == 'Widowed').astype(int)

    # === JOB FEATURES ===
    formal = ['Formally employed Government', 'Formally employed Private']
    df['has_formal_job'] = df['job_type'].isin(formal).astype(int)
    df['is_farmer'] = (df['job_type'] == 'Farming and Fishing').astype(int)
    df['is_informal'] = (df['job_type'] == 'Informally employed').astype(int)
    df['is_self_employed'] = (df['job_type'] == 'Self employed').astype(int)
    df['is_dependent'] = df['job_type'].isin(['Remittance Dependent', 'Government Dependent']).astype(int)

    # === BINNING ===
    df['age_group'] = pd.cut(df['age_of_respondent'], bins=[0,18,25,35,50,65,120], labels=[0,1,2,3,4,5]).astype(int)
    df['hh_group'] = pd.cut(df['household_size'], bins=[0,1,3,6,10,50], labels=[0,1,2,3,4]).astype(int)

    # === COUNTRY FEATURES ===
    for c in df['country'].unique():
        df[f'country_{c}'] = (df['country'] == c).astype(int)

    # === INTERACTIONS (CRITICAL FOR LOW MAE) ===
    df['edu_x_phone'] = df['edu_num'] * df['has_phone']
    df['edu_x_urban'] = df['edu_num'] * df['is_urban']
    df['edu_x_formal'] = df['edu_num'] * df['has_formal_job']
    df['phone_x_urban'] = df['has_phone'] * df['is_urban']
    df['edu_x_female'] = df['edu_num'] * df['is_female']
    df['age_x_edu'] = df['age_of_respondent'] * df['edu_num']
    df['urban_x_formal'] = df['is_urban'] * df['has_formal_job']
    df['phone_x_formal'] = df['has_phone'] * df['has_formal_job']
    df['edu_x_country_Kenya'] = df['edu_num'] * df['country_Kenya']
    df['phone_x_country_Kenya'] = df['has_phone'] * df['country_Kenya']

    # === COMPOSITE SCORE ===
    df['advantage_score'] = df['edu_num'] + df['has_phone']*2 + df['is_urban']*2 + df['has_formal_job']*3
    df['risk_score'] = (1-df['is_urban'])*2 + (1-df['has_phone'])*2 + (1-df['has_formal_job'])*2 + df['is_female']

    # === RATIOS ===
    df['age_hh_ratio'] = df['age_of_respondent'] / (df['household_size'] + 1)

    return df

print("\n🔧 Creating features...")
train = create_features(train)
test = create_features(test)

# ============================================================================
# PREPROCESS
# ============================================================================
# Drop original text columns (keep only numerical)
drop_cols = ['uniqueid', 'year', 'country', 'education_level', 'job_type',
             'marital_status', 'relationship_with_head', 'location_type',
             'cellphone_access', 'gender_of_respondent', 'bank_account']

X = train.drop([c for c in drop_cols if c in train.columns], axis=1)
y = train['bank_account']
X_test = test.drop([c for c in drop_cols if c in test.columns], axis=1)

# Scale
scaler = MinMaxScaler()
X_scaled = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)
X_test_scaled = pd.DataFrame(scaler.transform(X_test), columns=X_test.columns)

print(f"Features: {X_scaled.shape[1]}")

# ============================================================================
# CROSS-VALIDATION WITH OPTIMIZED MODELS
# ============================================================================
class_ratio = (y == 0).sum() / (y == 1).sum()

models = {
    'CatBoost': CatBoostClassifier(
        iterations=800, depth=7, learning_rate=0.03,
        l2_leaf_reg=3, scale_pos_weight=class_ratio,
        random_seed=42, verbose=0
    ),
    'LightGBM': LGBMClassifier(
        n_estimators=800, max_depth=7, learning_rate=0.03,
        num_leaves=63, min_child_samples=20,
        class_weight='balanced', reg_alpha=0.1, reg_lambda=0.1,
        random_state=42, verbose=-1
    )
}

print("\n🔄 5-Fold Cross-Validation...")
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

val_probs = {name: np.zeros(len(X_scaled)) for name in models}
test_probs = {name: np.zeros(len(X_test_scaled)) for name in models}
mae_scores = {name: [] for name in models}

for fold, (tr_idx, vl_idx) in enumerate(skf.split(X_scaled, y)):
    X_tr, X_vl = X_scaled.iloc[tr_idx], X_scaled.iloc[vl_idx]
    y_tr, y_vl = y.iloc[tr_idx], y.iloc[vl_idx]

    for name, model in models.items():
        model.fit(X_tr, y_tr)

        val_pred = model.predict_proba(X_vl)[:, 1]
        test_pred = model.predict_proba(X_test_scaled)[:, 1]

        val_probs[name][vl_idx] = val_pred
        test_probs[name] += test_pred / skf.n_splits

        mae = mean_absolute_error(y_vl, val_pred)
        mae_scores[name].append(mae)

# ============================================================================
# RESULTS
# ============================================================================
print(f"\n📊 INDIVIDUAL MODEL RESULTS")
for name in models:
    avg_mae = np.mean(mae_scores[name])
    print(f"{name:<12s}: MAE = {avg_mae:.5f}")

# Ensemble
final_val = (val_probs['CatBoost'] + val_probs['LightGBM']) / 2
final_test = (test_probs['CatBoost'] + test_probs['LightGBM']) / 2

ensemble_mae = mean_absolute_error(y, final_val)
print(f"\n🎯 ENSEMBLE MAE: {ensemble_mae:.5f}")

# ============================================================================
# SUBMISSION (PROBABILITIES!)
# ============================================================================
submission = pd.DataFrame({
    "uniqueid": test_uniqueid + " x " + test['country'],
    "bank_account": final_test
})
submission.to_csv('submission.csv', index=False)

print(f"\n✅ Submission saved!")
print(f"   File: submission.csv")
print(f"   Contains: PROBABILITIES (0 to 1)")
print(f"   Expected test MAE: ~{ensemble_mae:.5f}")
# Out:
# Target distribution:
# bank_account
# 0    0.859208
# 1    0.140792
# Name: proportion, dtype: float64
#
# 🔧 Creating features...
# Features: 33
#
# 🔄 5-Fold Cross-Validation...
#
# 📊 INDIVIDUAL MODEL RESULTS
# CatBoost    : MAE = 0.26720
# LightGBM    : MAE = 0.24774
#
# 🎯 ENSEMBLE MAE: 0.25747
#
# ✅ Submission saved!
#    File: submission.csv
#    Contains: PROBABILITIES (0 to 1)
#    Expected test MAE: ~0.25747

# %%
# ============================================================================
# SINGLE CATBOOST MODEL WITH TUNING + K-FOLD + DOWNLOAD
# ============================================================================
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import mean_absolute_error
from catboost import CatBoostClassifier
import warnings
warnings.filterwarnings('ignore')

# For downloading in Colab
from google.colab import files

# ============================================================================
# LOAD DATA
# ============================================================================
train = pd.read_csv('./Train.csv')
test = pd.read_csv('./Test.csv')
test_uniqueid = test['uniqueid']

# Encode target
le = LabelEncoder()
train['bank_account'] = le.fit_transform(train['bank_account'])

# ============================================================================
# FEATURE ENGINEERING
# ============================================================================
def create_features(df):
    df = df.copy()

    # Education numeric
    edu_map = {
        'No formal education': 0, 'Primary education': 1,
        'Secondary education': 2, 'Vocational/Specialised training': 3,
        'Tertiary education': 4, 'Other/Dont know/RTA': 0
    }
    df['edu_num'] = df['education_level'].map(edu_map)

    # Binary flags
    df['is_urban'] = (df['location_type'] == 'Urban').astype(int)
    df['has_phone'] = (df['cellphone_access'] == 'Yes').astype(int)
    df['is_female'] = (df['gender_of_respondent'] == 'Female').astype(int)
    df['is_married'] = (df['marital_status'] == 'Married/Living together').astype(int)
    df['is_head'] = (df['relationship_with_head'] == 'Head of Household').astype(int)
    df['is_widowed'] = (df['marital_status'] == 'Widowed').astype(int)

    # Job features
    formal = ['Formally employed Government', 'Formally employed Private']
    df['has_formal_job'] = df['job_type'].isin(formal).astype(int)
    df['is_farmer'] = (df['job_type'] == 'Farming and Fishing').astype(int)
    df['is_informal'] = (df['job_type'] == 'Informally employed').astype(int)
    df['is_self_employed'] = (df['job_type'] == 'Self employed').astype(int)

    # Binning
    df['age_group'] = pd.cut(df['age_of_respondent'], bins=[0,18,25,35,50,65,120], labels=[0,1,2,3,4,5]).astype(int)
    df['hh_group'] = pd.cut(df['household_size'], bins=[0,1,3,6,10,50], labels=[0,1,2,3,4]).astype(int)

    # Country dummies
    for c in df['country'].unique():
        df[f'country_{c}'] = (df['country'] == c).astype(int)

    # Interactions
    df['edu_x_phone'] = df['edu_num'] * df['has_phone']
    df['edu_x_urban'] = df['edu_num'] * df['is_urban']
    df['edu_x_formal'] = df['edu_num'] * df['has_formal_job']
    df['phone_x_urban'] = df['has_phone'] * df['is_urban']
    df['age_x_edu'] = df['age_of_respondent'] * df['edu_num']
    df['urban_x_formal'] = df['is_urban'] * df['has_formal_job']
    df['edu_x_country_Kenya'] = df['edu_num'] * df['country_Kenya']
    df['phone_x_country_Kenya'] = df['has_phone'] * df['country_Kenya']

    # Composite scores
    df['advantage_score'] = df['edu_num'] + df['has_phone']*2 + df['is_urban']*2 + df['has_formal_job']*3
    df['risk_score'] = (1-df['is_urban'])*2 + (1-df['has_phone'])*2 + (1-df['has_formal_job'])*2

    return df

print("🔧 Creating features...")
train = create_features(train)
test = create_features(test)

# ============================================================================
# PREPROCESS
# ============================================================================
drop_cols = ['uniqueid', 'year', 'country', 'education_level', 'job_type',
             'marital_status', 'relationship_with_head', 'location_type',
             'cellphone_access', 'gender_of_respondent', 'bank_account']

X = train.drop([c for c in drop_cols if c in train.columns], axis=1)
y = train['bank_account']
X_test = test.drop([c for c in drop_cols if c in test.columns], axis=1)

# Scale
scaler = MinMaxScaler()
X_scaled = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)
X_test_scaled = pd.DataFrame(scaler.transform(X_test), columns=X_test.columns)

print(f"Features: {X_scaled.shape[1]}")

# ============================================================================
# SINGLE CATBOOST MODEL WITH HYPERPARAMETERS + K-FOLD
# ============================================================================
class_ratio = (y == 0).sum() / (y == 1).sum()

# Best hyperparameters for low MAE
model = CatBoostClassifier(
    iterations=1000,              # More iterations for better learning
    depth=7,                      # Deeper trees for complex patterns
    learning_rate=0.03,           # Slow learning for precision
    l2_leaf_reg=5,                # Regularization to prevent overfitting
    border_count=254,             # More splits for accuracy
    scale_pos_weight=class_ratio, # Handle class imbalance
    subsample=0.8,                # Random sampling per tree
    colsample_bylevel=0.8,        # Feature sampling per level
    random_seed=42,
    verbose=0,
    early_stopping_rounds=100     # Stop if no improvement
)

print("\n🔄 5-Fold Cross-Validation...")
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

val_probs = np.zeros(len(X_scaled))
test_probs = np.zeros(len(X_test_scaled))
mae_scores = []

for fold, (tr_idx, vl_idx) in enumerate(skf.split(X_scaled, y)):
    X_tr, X_vl = X_scaled.iloc[tr_idx], X_scaled.iloc[vl_idx]
    y_tr, y_vl = y.iloc[tr_idx], y.iloc[vl_idx]

    # Train
    model.fit(X_tr, y_tr, eval_set=(X_vl, y_vl), verbose=False)

    # Predict probabilities
    val_pred = model.predict_proba(X_vl)[:, 1]
    test_pred = model.predict_proba(X_test_scaled)[:, 1]

    # Store
    val_probs[vl_idx] = val_pred
    test_probs += test_pred / skf.n_splits

    # Calculate MAE
    mae = mean_absolute_error(y_vl, val_pred)
    mae_scores.append(mae)

    print(f"   Fold {fold+1}: MAE = {mae:.5f}")

# ============================================================================
# RESULTS
# ============================================================================
print(f"\n{'='*50}")
print(f"📊 FINAL RESULTS")
print(f"{'='*50}")
print(f"Fold MAEs: {[f'{m:.5f}' for m in mae_scores]}")
print(f"Average MAE: {np.mean(mae_scores):.5f}")
print(f"Std MAE: {np.std(mae_scores):.5f}")
print(f"Best MAE: {np.min(mae_scores):.5f}")
print(f"Worst MAE: {np.max(mae_scores):.5f}")

# Overall MAE on all validation predictions
overall_mae = mean_absolute_error(y, val_probs)
print(f"\nOverall Validation MAE: {overall_mae:.5f}")

# ============================================================================
# CREATE SUBMISSION
# ============================================================================
submission = pd.DataFrame({
    "uniqueid": test_uniqueid + " x " + test['country'],
    "bank_account": test_probs  # ← PROBABILITIES (0 to 1)
})

# Save
submission.to_csv('submission.csv', index=False)

print(f"\n✅ Submission saved: submission.csv")
print(f"   Contains: PROBABILITIES (not labels)")
print(f"   Expected test MAE: ~{overall_mae:.5f}")

# ============================================================================
# DOWNLOAD FILE (FOR GOOGLE COLAB)
# ============================================================================
files.download('submission.csv')
print("\n📥 Download started for submission.csv")
# Out:
# 🔧 Creating features...
# Features: 29
#
# 🔄 5-Fold Cross-Validation...
#    Fold 1: MAE = 0.29329
#    Fold 2: MAE = 0.30180
#    Fold 3: MAE = 0.29472
#    Fold 4: MAE = 0.28940
#    Fold 5: MAE = 0.30150
#
# ...
# 📊 FINAL RESULTS
# ...
# Fold MAEs: ['0.29329', '0.30180', '0.29472', '0.28940', '0.30150']
# Average MAE: 0.29614
# Std MAE: 0.00482
# Best MAE: 0.28940
# Worst MAE: 0.30180
#
# Overall Validation MAE: 0.29614
#
# ✅ Submission saved: submission.csv
#    Contains: PROBABILITIES (not labels)
#    Expected test MAE: ~0.29614
# 📥 Download started for submission.csv

# %%
# RUN THIS FIRST - Tell me what you see
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder

train = pd.read_csv('./Train.csv')
test = pd.read_csv('./Test.csv')

le = LabelEncoder()
train['bank_account'] = le.fit_transform(train['bank_account'])

# CHECK 1: What does your target look like?
print("Target distribution:")
print(train['bank_account'].value_counts())
print(f"Class 0: {train['bank_account'].value_counts()[0]}")
print(f"Class 1: {train['bank_account'].value_counts()[1]}")

# CHECK 2: What does sample submission look like?
ss = pd.read_csv('./SampleSubmission.csv')
print(f"\nSample submission first 5 rows:")
print(ss.head())
print(f"\nSample submission value counts:")
print(ss['bank_account'].value_counts())
# Out:
# Target distribution:
# bank_account
# 0    20212
# 1     3312
# Name: count, dtype: int64
# Class 0: 20212
# Class 1: 3312
#
# Sample submission first 5 rows:
#             unique_id  bank_account
# 0  uniqueid_1 x Kenya             0
# 1  uniqueid_2 x Kenya             0
# 2  uniqueid_3 x Kenya             0
# 3  uniqueid_4 x Kenya             0
# 4  uniqueid_5 x Kenya             0
#
# Sample submission value counts:
# bank_account
# 0    33610
# Name: count, dtype: int64

# %%
# If submission should be 0 or 1:
submission = pd.DataFrame({
    "uniqueid": test['uniqueid'] + " x " + test['country'],
    "bank_account": model.predict(X_test_scaled)  # Labels (0/1)
})

# If submission should be probabilities:
submission = pd.DataFrame({
    "uniqueid": test['uniqueid'] + " x " + test['country'],
    "bank_account": model.predict_proba(X_test_scaled)[:, 1]  # Probabilities
})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2379/2480257700.py in <cell line: 0>()
#       1 # If submission should be 0 or 1:
# ----> 2 submission = pd.DataFrame({
#       3     "uniqueid": test['uniqueid'] + " x " + test['country'],
#       4     "bank_account": model.predict(X_test_scaled)  # Labels (0/1)
#       5 })
#
# NameError: name 'pd' is not defined

# %%
# Core libraries
import pandas as pd
import numpy as np

# Install CatBoost if not already installed
# !pip install catboost

# Model
from catboost import CatBoostClassifier

# Evaluation
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_auc_score, f1_score
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.1/97.1 MB 8.3 MB/s eta 0:00:00
# ...

# %%
train = pd.read_csv("Train.csv")
test = pd.read_csv("Test.csv")

# %%
# Convert Yes/No → 1/0
train['bank_account'] = train['bank_account'].map({'Yes':1, 'No':0})

# Separate features and target
X = train.drop('bank_account', axis=1)
y = train['bank_account']

# %%
# Combine for consistent processing
full = pd.concat([X, test], axis=0)

# Age features
full['age_group'] = pd.cut(full['age_of_respondent'],
                           bins=[15,25,35,50,100],
                           labels=['youth','young','adult','senior'])

full['age_squared'] = full['age_of_respondent'] ** 2

# Household pressure
full['dependency_ratio'] = full['household_size'] / full['age_of_respondent']

# Access features
full['has_phone'] = full['cellphone_access'].map({'Yes':1,'No':0})
full['is_urban'] = (full['location_type'] == 'Urban').astype(int)

# Strong interaction features
full['edu_job'] = full['education_level'] + "_" + full['job_type']
full['country_edu'] = full['country'] + "_" + full['education_level']
full['loc_phone'] = full['location_type'] + "_" + full['cellphone_access']

# Social features
full['is_married'] = full['marital_status'].isin(['Married','Polygamous']).astype(int)
full['is_head'] = (full['relationship_with_head'] == 'Head of Household').astype(int)

# %%
X_processed = full.iloc[:len(X), :]
X_test = full.iloc[len(X):, :]

# %%
X_train, X_val, y_train, y_val = train_test_split(
    X_processed, y,
    test_size=0.1,
    stratify=y,
    random_state=42
)

# %%
# CatBoost handles categorical features directly
cat_cols = X_processed.select_dtypes(include=['object', 'category']).columns.tolist()

# %%
cat_model = CatBoostClassifier(
    iterations=1500,
    depth=6,
    learning_rate=0.03,
    loss_function='Logloss',
    eval_metric='AUC',
    random_seed=42,
    verbose=200
)

# %%
cat_model.fit(
    X_train, y_train,
    cat_features=cat_cols,
    eval_set=(X_val, y_val),
    early_stopping_rounds=100
)
# Out:
# 0:	test: 0.8252060	best: 0.8252060 (0)	total: 162ms	remaining: 4m 2s
# 200:	test: 0.8745372	best: 0.8746261 (195)	total: 13.2s	remaining: 1m 25s
# 400:	test: 0.8752731	best: 0.8754725 (366)	total: 25.5s	remaining: 1m 9s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.8754725213
# bestIteration = 366
#
# Shrink model to first 367 iterations.
# CatBoostClassifier(depth=6, eval_metric='AUC', iterations=1500, learning_rate=0.03, loss_function='Logloss', random_seed=42, verbose=200)

# %%
# Predict probabilities
y_pred_prob = cat_model.predict_proba(X_val)[:,1]

# Convert to binary
y_pred = (y_pred_prob > 0.5).astype(int)

# Metrics
print("Accuracy:", accuracy_score(y_val, y_pred))
print("ROC-AUC:", roc_auc_score(y_val, y_pred_prob))
print("F1 Score:", f1_score(y_val, y_pred))
# Out:
# Accuracy: 0.8903527411814705
# ROC-AUC: 0.8754725212989442
# F1 Score: 0.484

# %%
import matplotlib.pyplot as plt

cat_model.get_feature_importance(prettified=True).head(15)
# Out:
#                 Feature Id  Importances
# 0                loc_phone    26.360900
# 1              country_edu    10.332995
# 2                  edu_job     8.600337
# 3                  country     8.264301
# 4        age_of_respondent     7.627843
# 5                 job_type     5.922588
# 6          education_level     4.984043
# 7     gender_of_respondent     4.414884
# 8              age_squared     4.222700
# 9   relationship_with_head     4.047805
# 10               age_group     3.078957
# 11        cellphone_access     2.940996
# 12          marital_status     2.676434
# 13                 is_head     1.818905
# 14        dependency_ratio     1.150314

# %%
# Train on full data
cat_model.fit(X_processed, y, cat_features=cat_cols)

# Predict test
test_preds = cat_model.predict_proba(X_test)[:,1]

# Convert to binary
final_preds = (test_preds > 0.5).astype(int)

# Submission format
submission = pd.DataFrame({
    "uniqueid": test['uniqueid'] + " x " + test['country'],
    "bank_account": final_preds
})

submission.to_csv("catboost_submission.csv", index=False)

print("✅ High-accuracy submission file ready!")
# Out:
# 0:	total: 64.7ms	remaining: 1m 37s
# 200:	total: 14s	remaining: 1m 30s
# 400:	total: 26.8s	remaining: 1m 13s
# 600:	total: 40.8s	remaining: 1m 1s
# 800:	total: 55.8s	remaining: 48.7s
# 1000:	total: 1m 10s	remaining: 35.3s
# 1200:	total: 1m 24s	remaining: 21.1s
# 1400:	total: 1m 39s	remaining: 7.01s
# 1499:	total: 1m 45s	remaining: 0us
# ✅ High-accuracy submission file ready!
